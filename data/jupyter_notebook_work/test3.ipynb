# %% [markdown]
# # this is a test

# %% [markdown]
# ## dec1

# %%
from sklearn import tree
feature = [[178,1],[155,0],[158,0],[173,0],[165,0],[170,1],[177,1]]
label = ['male', 'female', 'female', 'male', 'female', 'male', 'male']
clf = tree.DecisionTreeClassifier()
clf = clf.fit(feature, label)
clf.predict([[176,1]])
# Out:
# array(['male'], dtype='<U6')

# %%
from numpy import *
x = random.rand(4,4)
y = mat(x)
y
# Out:
# matrix([[0.54314428, 0.99688847, 0.16506328, 0.16607809],
#         [0.58621506, 0.01341328, 0.35853993, 0.46620948],
#         [0.05301162, 0.18861917, 0.48665789, 0.3961378 ],
#         [0.97302067, 0.03172027, 0.80090137, 0.29504093]])

# %%
3782.75*12
# Out:
# 45393.0

# %% [markdown]
# ## opencv2 test

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img =cv2.imread('test_images/a.jpg')
plt.imshow(img)
plt.xticks([]),plt.yticks([])  #to hide tick values on X and Y axis
plt.show()
# import cv2
# from IPython.display import Image
# Image('test_images/a.jpg')
# img = cv2.imread('test_images/a.jpg')
# cv2.namedWindow('image',cv2.WINDOW_NORMAL)
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
cv2.imwrite('test_iamges/a1.jpg',img)
# Out:
# False

# %% [markdown]
# ## test %matplotlib inline

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
labels='frogs','hogs','dogs','logs'
sizes=15,20,45,10
colors='yellowgreen','gold','lightskyblue','lightcoral'
explode=0,0.1,0,0
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=50)
plt.axis('equal')
plt.show()
